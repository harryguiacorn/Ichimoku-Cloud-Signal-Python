# %% [markdown]
# <a href="https://colab.research.google.com/github/harryguiacorn/Cloud-Signal-Python/blob/master/Colab_Cloud_Signal_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/harryguiacorn/Cloud-Signal-Python.git
# Out:
# Cloning into 'Cloud-Signal-Python'...
# remote: Enumerating objects: 4653, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 4653 (delta 103), reused 89 (delta 69), pack-reused 4520
# Receiving objects: 100% (4653/4653), 16.79 MiB | 11.52 MiB/s, done.
# Resolving deltas: 100% (1118/1118), done.

# %%
# %cd Cloud-Signal-Python/
# !ls
# Out:
# /content/Cloud-Signal-Python
# asset_list  misc	 pyproject.toml  replit.nix	   src
# main.py     poetry.lock  README.md	 requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: appdirs==1.4.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: beautifulsoup4==4.11.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (4.11.2)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: cffi==1.15.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (1.15.1)
# Collecting charset-normalizer==3.1.0
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: contourpy==1.0.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (1.0.7)
# Collecting cryptography==39.0.2
#   Downloading cryptography-39.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: cycler==0.11.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (0.11.0)
# Collecting finta==1.3
#   Downloading finta-1.3-py3-none-any.whl (29 kB)
# Collecting fonttools==4.39.0
#   Downloading fonttools-4.39.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.7 MB/s eta 0:00:00
# Collecting frozendict==2.3.5
#   Downloading frozendict-2.3.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 KB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: html5lib==1.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (1.1)
# Requirement already satisfied: idna==3.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 13)) (3.4)
# Requirement already satisfied: kiwisolver==1.4.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (1.4.4)
# Requirement already satisfied: lxml==4.9.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 15)) (4.9.2)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 16)) (3.7.1)
# Requirement already satisfied: multitasking==0.0.11 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (0.0.11)
# Collecting numpy==1.24.2
#   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 43.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging==23.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 19)) (23.0)
# Collecting pandas==1.5.3
#   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas-datareader==0.10.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 21)) (0.10.0)
# Collecting Pillow==9.4.0
#   Downloading Pillow-9.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 68.6 MB/s eta 0:00:00
# Requirement already satisfied: plotly==5.13.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 23)) (5.13.1)
# Requirement already satisfied: pycparser==2.21 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 24)) (2.21)
# Requirement already satisfied: pyparsing==3.0.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 25)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 26)) (2.8.2)
# Requirement already satisfied: pytz==2022.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 27)) (2022.7.1)
# Collecting requests==2.28.2
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 29)) (1.16.0)
# Requirement already satisfied: soupsieve==2.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 30)) (2.4)
# Collecting tapy==1.9.1
#   Downloading tapy-1.9.1-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: tenacity==8.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 32)) (8.2.2)
# Collecting urllib3==1.26.14
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 34)) (0.5.1)
# Collecting yapf==0.32.0
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 12.4 MB/s eta 0:00:00
# Collecting yfinance==0.2.12
#   Downloading yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 16)) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib==3.7.1->-r requirements.txt (line 16)) (3.15.0)
# Installing collected packages: yapf, urllib3, Pillow, numpy, frozendict, fonttools, charset-normalizer, requests, pandas, cryptography, yfinance, tapy, finta
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.3.6
#     Uninstalling frozendict-2.3.6:
#       Successfully uninstalled frozendict-2.3.6
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.39.3
#     Uninstalling fonttools-4.39.3:
#       Successfully uninstalled fonttools-4.39.3
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 40.0.1
#     Uninstalling cryptography-40.0.1:
#       Successfully uninstalled cryptography-40.0.1
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.14
#     Uninstalling yfinance-0.2.14:
#       Successfully uninstalled yfinance-0.2.14
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# Successfully installed Pillow-9.4.0 charset-normalizer-3.1.0 cryptography-39.0.2 finta-1.3 fonttools-4.39.0 frozendict-2.3.5 numpy-1.24.2 pandas-1.5.3 requests-2.28.2 tapy-1.9.1 urllib3-1.26.14 yapf-0.32.0 yfinance-0.2.12

# %%
# !python main.py
# Out:
# ******************* Reading symbols *******************
#    symbol                      name
# 0     MMM                        3M
# 1     AXP          American Express
# 2    AMGN                     Amgen
# 3    AAPL                     Apple
# 4      BA                    Boeing
# 5     CAT               Caterpillar
# 6     CVX                   Chevron
# 7    CSCO                     Cisco
# 8      KO                 Coca-Cola
# 9     DIS                    Disney
# 10    DOW                       Dow
# 11     GS             Goldman Sachs
# 12     HD                Home Depot
# 13    HON                 Honeywell
# 14    IBM                       IBM
# 15   INTC                     Intel
# 16    JNJ         Johnson & Johnson
# 17    JPM            JPMorgan Chase
# 18    MCD                McDonald's
# 19    MRK                     Merck
# 20   MSFT                 Microsoft
# 21    NKE                      Nike
# 22     PG          Procter & Gamble
# 23    CRM                Salesforce
# 24    TRV                 Travelers
# 25    UNH        UnitedHealth Group
# 26     VZ                   Verizon
# 27      V                      Visa
# 28    WBA  Walgreens Boots Alliance
# 29    WMT                   Walmart
# ******************* Downloading from Yahoo *******************
# [*********************100%***********************]  1 of 1 completed
# 0 MMM -> data/dowjones30/d/MMM.csv
# [*********************100%***********************]  1 of 1 completed
# 1 AXP -> data/dowjones30/d/AXP.csv
# [*********************100%***********************]  1 of 1 completed
# 2 AMGN -> data/dowjones30/d/AMGN.csv
# [*********************100%***********************]  1 of 1 completed
# 3 AAPL -> data/dowjones30/d/AAPL.csv
# [*********************100%***********************]  1 of 1 completed
# 4 BA -> data/dowjones30/d/BA.csv
# [*********************100%***********************]  1 of 1 completed
# 5 CAT -> data/dowjones30/d/CAT.csv
# [*********************100%***********************]  1 of 1 completed
# 6 CVX -> data/dowjones30/d/CVX.csv
# [*********************100%***********************]  1 of 1 completed
# 7 CSCO -> data/dowjones30/d/CSCO.csv
# [*********************100%***********************]  1 of 1 completed
# 8 KO -> data/dowjones30/d/KO.csv
# [*********************100%***********************]  1 of 1 completed
# 9 DIS -> data/dowjones30/d/DIS.csv
# [*********************100%***********************]  1 of 1 completed
# 10 DOW -> data/dowjones30/d/DOW.csv
# [*********************100%***********************]  1 of 1 completed
# 11 GS -> data/dowjones30/d/GS.csv
# [*********************100%***********************]  1 of 1 completed
# 12 HD -> data/dowjones30/d/HD.csv
# [*********************100%***********************]  1 of 1 completed
# 13 HON -> data/dowjones30/d/HON.csv
# [*********************100%***********************]  1 of 1 completed
# 14 IBM -> data/dowjones30/d/IBM.csv
# [*********************100%***********************]  1 of 1 completed
# 15 INTC -> data/dowjones30/d/INTC.csv
# [*********************100%***********************]  1 of 1 completed
# 16 JNJ -> data/dowjones30/d/JNJ.csv
# [*********************100%***********************]  1 of 1 completed
# 17 JPM -> data/dowjones30/d/JPM.csv
# [*********************100%***********************]  1 of 1 completed
# 18 MCD -> data/dowjones30/d/MCD.csv
# [*********************100%***********************]  1 of 1 completed
# 19 MRK -> data/dowjones30/d/MRK.csv
# [*********************100%***********************]  1 of 1 completed
# 20 MSFT -> data/dowjones30/d/MSFT.csv
# [*********************100%***********************]  1 of 1 completed
# 21 NKE -> data/dowjones30/d/NKE.csv
# [*********************100%***********************]  1 of 1 completed
# 22 PG -> data/dowjones30/d/PG.csv
# [*********************100%***********************]  1 of 1 completed
# 23 CRM -> data/dowjones30/d/CRM.csv
# [*********************100%***********************]  1 of 1 completed
# 24 TRV -> data/dowjones30/d/TRV.csv
# [*********************100%***********************]  1 of 1 completed
# 25 UNH -> data/dowjones30/d/UNH.csv
# [*********************100%***********************]  1 of 1 completed
# 26 VZ -> data/dowjones30/d/VZ.csv
# [*********************100%***********************]  1 of 1 completed
# 27 V -> data/dowjones30/d/V.csv
# [*********************100%***********************]  1 of 1 completed
# 28 WBA -> data/dowjones30/d/WBA.csv
# [*********************100%***********************]  1 of 1 completed
# 29 WMT -> data/dowjones30/d/WMT.csv
# ++++++++++++++++++++ Creating Ichimoku Data ++++++++++++++++++++
# Ichimoku columns added to csv
# -------------------- Generating Cloud Signals --------------------
# Cloud signal count csv files are created
# ********************Creating Cloud Signal Aggregator ********************
# self.model.isIntraday:: False
# __symbol:: MMM , entries:  126
# __symbol:: AXP , entries:  126
# __symbol:: AMGN , entries:  126
# __symbol:: AAPL , entries:  126
# __symbol:: BA , entries:  126
# __symbol:: CAT , entries:  126
# __symbol:: CVX , entries:  126
# __symbol:: CSCO , entries:  126
# __symbol:: KO , entries:  126
# __symbol:: DIS , entries:  126
# __symbol:: DOW , entries:  126
# __symbol:: GS , entries:  126
# __symbol:: HD , entries:  126
# __symbol:: HON , entries:  126
# __symbol:: IBM , entries:  126
# __symbol:: INTC , entries:  126
# __symbol:: JNJ , entries:  126
# __symbol:: JPM , entries:  126
# __symbol:: MCD , entries:  126
# __symbol:: MRK , entries:  126
# __symbol:: MSFT , entries:  126
# __symbol:: NKE , entries:  126
# __symbol:: PG , entries:  126
# __symbol:: CRM , entries:  126
# __symbol:: TRV , entries:  126
# __symbol:: UNH , entries:  126
# __symbol:: VZ , entries:  126
# __symbol:: V , entries:  126
# __symbol:: WBA , entries:  126
# __symbol:: WMT , entries:  126
# Aggregator DowJones30-cloud-D.csv and .xml are created
# -------------------- Generating TKx Signals --------------------
# TKx count csv files are created
# ********************Creating TKx Signal Aggregator ********************
# self.model.isIntraday:: False
# __symbol:: MMM , entries:  126
# __symbol:: AXP , entries:  126
# __symbol:: AMGN , entries:  126
# __symbol:: AAPL , entries:  126
# __symbol:: BA , entries:  126
# __symbol:: CAT , entries:  126
# __symbol:: CVX , entries:  126
# __symbol:: CSCO , entries:  126
# __symbol:: KO , entries:  126
# __symbol:: DIS , entries:  126
# __symbol:: DOW , entries:  126
# __symbol:: GS , entries:  126
# __symbol:: HD , entries:  126
# __symbol:: HON , entries:  126
# __symbol:: IBM , entries:  126
# __symbol:: INTC , entries:  126
# __symbol:: JNJ , entries:  126
# __symbol:: JPM , entries:  126
# __symbol:: MCD , entries:  126
# __symbol:: MRK , entries:  126
# __symbol:: MSFT , entries:  126
# __symbol:: NKE , entries:  126
# __symbol:: PG , entries:  126
# __symbol:: CRM , entries:  126
# __symbol:: TRV , entries:  126
# __symbol:: UNH , entries:  126
# __symbol:: VZ , entries:  126
# __symbol:: V , entries:  126
# __symbol:: WBA , entries:  126
# __symbol:: WMT , entries:  126
# Aggregator DowJones30-tkx-D.csv and .xml are created
